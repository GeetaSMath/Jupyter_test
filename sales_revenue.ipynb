# %%
import pandas as pd
import numpy as np

# Load CSV file
df_csvdata=pd.read_csv(r'C:\Users\Admin\Desktop\sales2017_raw - sales2017_raw.csv')
print(df_csvdata)

df_csvdata.info()
# Out:
#               Unnamed: 0  \
# 0                    NaN
# 1      order_id (unique)
# 2                    NaN
# 3                      1
# 4                    NaN
# ...                  ...
# 18121              18113
# 18122              18114
# 18123              18115
# 18124              18116
# 18125              18117
#
#       Sales data from an e-commerce store // The company wants to have the sales analyzed including promotions and delivery time  \
# 0                                                    NaN
# 1                                             product_id
# 2                                                    NaN
# 3                                                  P0258
# 4                                                    NaN
# ...                                                  ...
# 18121                                              P0348
# 18122                                              P0585
# 18123                                              P0223
# ...
